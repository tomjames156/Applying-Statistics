# %%
import pandas as pd

df = pd.read_excel("Regression.xlsx", sheet_name='coords')
df
# Out:
#    x  y
# 0 -2 -3
# 1 -1 -1
# 2  1  2
# 3  4  3

# %%
df.y.std()
# Out:
# np.float64(2.753785273643051)

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 8))
ax.scatter(data=df, x='x', y='y')
ax.plot([0.5, 11], [0.25, 10.5], 'o-r')
ax.plot([0, -3, 10], [2.75, 2.75, 2.75], 'o-g')
ax.plot(x_coords, y_coords, '-r')
plt.xlim(-3, 10)
plt.show()

# %%
import seaborn as sns

sns.residplot(df, x='x', y='y')
plt.show()

# %%
# !{sys.executable} -m pip install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 306.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 4.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.2.3/libexec/bin/python -m pip install --upgrade pip

# %%
# Creating the linear regression model

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model = model.fit(df[['x']], df['y'])

# %%
import numpy as np

# %%
# Get the arrary of x coords for the regression line

x_coords = np.arange(-3, 5).reshape(-1, 1)
x_coords
# Out:
# array([[-3],
#        [-2],
#        [-1],
#        [ 0],
#        [ 1],
#        [ 2],
#        [ 3],
#        [ 4]])

# %%
y_coords = model.predict(x_coords)
y_coords
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-3.16666667, -2.19047619, -1.21428571, -0.23809524,  0.73809524,
#         1.71428571,  2.69047619,  3.66666667])
